# %%
#int

x = 1234

y = x

isinstance(x,y)
# Out:
# Running cells with '.venv (3.14.2) (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Semire/Downloads/My Programming Journey 3/Testing-repo/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
